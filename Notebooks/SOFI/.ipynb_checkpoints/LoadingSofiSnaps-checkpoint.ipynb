# %%
import numpy as np
import os
import segyio

from plotting_support import explode_volume

# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # PARAMS

# %%
dx = 0.01
nx = nz = 50
ny=50

npad = 0
FS = False 

sloc = np.array([0.25, 0.25, 0.25]) # in m
sloc_gp = ((sloc/dx)-1).astype('int')

nrec = 150

print(sloc_gp)
# Out:
# [24 24 24]

# %% [markdown]
# # SNAPS

# %%
snap_path = '../../../SOFI-modelling/SOFI_LabImitiation/outputs/snap'
p_wave_file = os.path.join(snap_path,'test.bin.div')
s_wave_file = os.path.join(snap_path,'test.bin.curl')

# %%
p_snaps_1d = np.fromfile(p_wave_file,dtype='<f')
print(p_snaps_1d.shape)
# Out:
# (12750000,)

# %%
nsnaps = int(p_snaps_1d.shape[0]/(nx*ny*nz))

nsnaps
# Out:
# 102

# %%
p_snaps = p_snaps_1d.reshape([nsnaps, nx, nz, ny])
p_snaps = np.transpose(p_snaps,[0,3,2,1])
p_snaps.shape
# Out:
# (102, 50, 50, 50)

# %%
print(np.min(p_snaps), np.max(p_snaps))
# Out:
# -510415.62 464602.16

# %%
np.unravel_index(np.argmax(p_snaps),p_snaps.shape)
# Out:
# (6, 24, 24, 24)

# %%
p_snaps_nopad = p_snaps  #[:,:-30,30:-30,30:-30]

# %%
explode_volume(p_snaps_nopad[1], p=99.8,
               x=sloc_gp[0], y=sloc_gp[2], t=sloc_gp[1])
#                tlim=[0, t[-1]], tlabel=r'$t$',
#                    xlim=[x[0]/1e3, x[-1]/1e3], xlabel=r'$x_r$',
#                    ylim=[y[0]/1e3, y[-1]/1e3], ylabel=r'$y_r$',
#                    labels= ('[s]', '[km]', '[km]'),
#                    clipval=(-0.5, 0.5), figsize=(8, 8), 
#                    title='Data')
# Out:
# (<Figure size 800x800 with 3 Axes>,
#  (<Axes: xlabel='x samples', ylabel='t samples'>,
#   <Axes: xlabel='y samples'>,
#   <Axes: ylabel='y samples'>))

# %%
fig,axs = plt.subplots(4,7, figsize=[15,15])
for i,snap in enumerate(p_snaps_nopad):
    axs.ravel()[i].imshow(snap[:,:,sloc_gp[2]],  cmap='binary', vmin=-1e3, vmax=1e3)
    axs.ravel()[i].set_title('t step %i'%i)
# for ax in axs.ravel(): ax.set_yticks([]); ax.set_xticks([])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 3
#       1 fig,axs = plt.subplots(4,7, figsize=[15,15])
#       2 for i,snap in enumerate(p_snaps_nopad):
# ----> 3     axs.ravel()[i].imshow(snap[:,:,sloc_gp[2]],  cmap='binary', vmin=-1e3, vmax=1e3)
#       4     axs.ravel()[i].set_title('t step %i'%i)
#       5 # for ax in axs.ravel(): ax.set_yticks([]); ax.set_xticks([])
#
# IndexError: index 28 is out of bounds for axis 0 with size 28

# %% [markdown]
# # DATA

# %%
data_path = '../../../SOFI-modelling/SOFI_LabImitiation/outputs/su'
vz_path = os.path.join(data_path,'test_div.txt')
# s_wave_file = os.path.join(data_path,'test.bin.curl')

# %%
nr = nrec
vz_flat = np.loadtxt(vz_path,delimiter="\n")
nt = int(vz_flat.shape[0]/nr)
print('nt:%i, nr:%i'%(nt,nr))
try: 
    vz_flat.reshape((nr,nt))
except:
    print('Not good dims \n nt:%i nr:%i \n vz flat:%i'%(nt,nr,vz_flat.shape[0]))
    
vz = vz_flat[:nt*nr].reshape((nr,nt))
print(np.max(vz))
# Out:
# nt:10000, nr:150
# 1570.833

# %%
vlim=np.percentile(vz[:,:1500],99.5)
              
plt.figure(figsize=[15,10])
plt.imshow(vz[:,:1500].T, aspect='auto', cmap='binary', vmin=-vlim, vmax=vlim)

# %%
vz_flat = np.loadtxt(vz_path,delimiter="\n")
vz_flat[1050]
