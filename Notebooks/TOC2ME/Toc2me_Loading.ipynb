# %%
import numpy as np

# %%
data = np.load('/home/birniece/Documents/data/ToC2ME/14to15.npy')

# %%
from pyfrac.visualisation.traceviz import traceimage, wiggleplot

# %%
data.shape
# Out:
# (69, 1800001)

# %%
traceimage(data)
# Out:
# (<Figure size 1200x600 with 2 Axes>,
#  <Axes: title={'center': 'Seismic Recording'}, xlabel='Receiver #', ylabel='Time'>)

# %%
dt=0.002
t = np.arange(0,(data.shape[1]*dt),dt)
t_min = np.arange(0,(data.shape[1]*dt)/60,dt)

ev_window = data[:, 15750:16750]
wiggleplot(ev_window[::5])
# Out:
# (<Figure size 1200x600 with 14 Axes>,
#  array([<Axes: ylabel='0'>, <Axes: ylabel='1'>, <Axes: ylabel='2'>,
#         <Axes: ylabel='3'>, <Axes: ylabel='4'>, <Axes: ylabel='5'>,
#         <Axes: ylabel='6'>, <Axes: ylabel='7'>, <Axes: ylabel='8'>,
#         <Axes: ylabel='9'>, <Axes: ylabel='10'>, <Axes: ylabel='11'>,
#         <Axes: ylabel='12'>, <Axes: xlabel='Time samples', ylabel='13'>],
#        dtype=object))
