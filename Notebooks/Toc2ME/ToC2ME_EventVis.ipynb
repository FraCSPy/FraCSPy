# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

import numpy as np
import matplotlib.pyplot as plt
import os
import glob
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from obspy import read

# %%
event_folder = "/home/birniece/Documents/data/ToC2ME/Omar/EV1115_173305/"
event_files =  sorted(glob.glob(event_folder+'*.mseed'), key=lambda x: int(os.path.basename(x).split('/')[-1][:-6]))
print(event_files)
# Out:
# ['/home/birniece/Documents/data/ToC2ME/Omar/EV1115_173305/1107.mseed', '/home/birniece/Documents/data/ToC2ME/Omar/EV1115_173305/1108.mseed', '/home/birniece/Documents/data/ToC2ME/Omar/EV1115_173305/1109.mseed', '/home/birniece/Documents/data/ToC2ME/Omar/EV1115_173305/1111.mseed', '/home/birniece/Documents/data/ToC2ME/Omar/EV1115_173305/1112.mseed', '/home/birniece/Documents/data/ToC2ME/Omar/EV1115_173305/1113.mseed', '/home/birniece/Documents/data/ToC2ME/Omar/EV1115_173305/1114.mseed', '/home/birniece/Documents/data/ToC2ME/Omar/EV1115_173305/1116.mseed', '/home/birniece/Documents/data/ToC2ME/Omar/EV1115_173305/1118.mseed', '/home/birniece/Documents/data/ToC2ME/Omar/EV1115_173305/1119.mseed', '/home/birniece/Documents/data/ToC2ME/Omar/EV1115_173305/1120.mseed', '/home/birniece/Documents/data/ToC2ME/Omar/EV1115_173305/1121.mseed', '/home/birniece/Documents/data/ToC2ME/Omar/EV1115_173305/1122.mseed', '/home/birniece/Documents/data/ToC2ME/Omar/EV1115_173305/1123.mseed', '/home/birniece/D
# ...

# %%
trace_data = np.zeros([69,12000])
for i,evf in enumerate(event_files):
    st = read(evf)
    trace_data[i] = st[0].data

# %%
st[0].stats
# Out:
#          network: 5B
#          station: 1215
#         location: 00
#          channel: DH1
#        starttime: 2016-11-15T17:32:58.550000Z
#          endtime: 2016-11-15T17:33:22.548000Z
#    sampling_rate: 500.0
#            delta: 0.002
#             npts: 12000
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'dataquality': 'M', 'number_of_records': 106, 'encoding': 'FLOAT32', 'byteorder': '>', 'record_length': 512, 'filesize': 162816})

# %%
plt.imshow(trace_data[:,3500:4500].T, aspect='auto', cmap='RdBu', vmin=-1e-2, vmax=1e-2)

# %%
st[0].data.shape
# Out:
# (12000,)

# %%
st[0].data
# Out:
# array([-2.1342810e-05, -2.1342810e-05, -3.5571349e-05, ...,
#        -2.4899945e-04, -9.9599776e-05, -1.7074248e-04], dtype=float32)
